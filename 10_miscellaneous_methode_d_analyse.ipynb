# %% [markdown]
# # Méthode d'analyse

# %% [markdown]
# # - 1) imports

# %%
sheetname = None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
from jr_data_science import functions_de_decouverte_de_fichiers
from jr_data_science import useful_functions

# %%
def format_euro(nombre, devise=u"€"):
    nombre = format_nombre(nombre)
    return " ".join([nombre, devise])


def format_nombre(nombre):
    import numpy as np
    if np.isnan(nombre):
        return "0"

    nombre = float(nombre)
    if nombre < 1e3:
        return "{:.1f}".format(nombre)
    if nombre < 1e6:
        return "{:.1f}K".format(nombre / 1e3)
    if nombre < 1e9:
        return "{:.1f}M".format(nombre / 1e6)
    if nombre < 1e12:
        return "{:.1f}G".format(nombre / 1e9)
    return str(nombre)

# %%
def print_list_as_dict(liste):
    print("dico = {")
    for key in liste:
        print("\"{key}\" : str ,".format(key=key))
    print("}")

# %%
def print_col_as_dict(df):
    """
    Générateur de code : affiche à l'écran la liste des colonnes d'une DF sous forme de dico.
    """
    print("dtypes = {")
    for col in df.columns:
        print("\"{col}\" : str ,".format(col=col))
    print("}")
    print("""
# => changez les types dans les colonnes, et mettez les dates et colonnes de catégories dans les tableaux ci dessous")
dayfirst = -1
parse_dates = []
categories = []
# rechargez la df avec les colonnes indiquées
df = pd.read
df = pd.read_csv(path, sep=sep, dtype=dtypes, parse_dates=parse_dates, dayfrist=dayfirst)
df.shape, df.dtypes
# vous pouvez aussi générer du code ensuite pour les colonnes catégorielles
for col in categories:
code_for_cat_col(df, col)    
    """)

# %%
def analyse_to_excel(df, filename, output_dir="."):
    """
    Construit un fichier csv avec une analyse de chaque colonne de la df => à importer dans excel en tant que tsv.

    """
    import os
    output_file = os.path.join(output_dir, "%s_analyse.csv"%filename)
    
    fichier = [" "]*15
    nz      = 0
    n_col   = -1
    with open(output_file, "w", encoding="utf-8") as f:
        f.write("%s lignes, %s col"%df.shape)
    for col in df.columns:
            print(col)
            n_col        += 1
            nb_valeur     = df[col].value_counts().shape[0]
            nb_null       = df[col].isnull().sum()
            n             = 10
            top_n         = df[col].value_counts().sort_values(ascending=False).reset_index()[:n].values
            pct_top_n     = [x[1]/df.shape[0] for x in top_n]
            fichier[0]   += "\t%s\t  _ \t  _ "%(col)
            fichier[1]   += "\tnb_valeur \t%s \t _"%nb_valeur
            fichier[2]   += "\tnb_null \t %s \t _"%(nb_null)
            current_ligne = 2
            for ((x,y),z) in zip(top_n, pct_top_n):
                current_ligne += 1
                fichier[current_ligne] += "\t%s\t %s \t %.2f"%(x,y,z)
            while current_ligne<14:
                current_ligne += 1
                fichier[current_ligne] += "\t%s\t %s \t %s"%("_","_","_")
            if n_col>0:
                if n_col %4==0:        
                    print(n_col)
                    with open(output_file, "a", encoding="utf-8") as f:
                        for line in fichier:
                            f.write(line+"\n")
                    fichier = [" "]*15
    with open(output_file, "a", encoding="utf-8") as f:
        for line in fichier:
            f.write(line+"\n")
            
    print("Wrote into %s"%(output_file))

# %%
def code_for_cat_col(df, col):
    """
    Generate a python string to help transforming a pandas column into a categorie.
    """
    print("from pandas.api.types import CategoricalDtype")
    to_print = "cat = CategoricalDtype(categories=["
    for x in sorted(df[col].unique()):
        to_print += "\'%s\',"%x
    to_print += "], ordered=True)"
    print(to_print)
    print("#df['%s'] = df['%s'].astype(cat)"%(col, col))

# %%
def plot_pivot(graph):
    tab = graph["df"].pivot_table(**graph["pivot"])
    sns.heatmap(tab.sort_index(), cmap="PiYG", center=0)
    plt.title(graph["title"]);

# %%
def print_cols(liste):
    for i,x in enumerate(liste):
        print("%s : %s"%(i,x))

# %% [markdown]
# # 0) chargement des données

# %%
data_dir = "/Users/romain/Google Drive/ayming/BAT_DATAS"

# %%
file_extension = ".csv"
file_extension = ".xlsx"
csvs = functions_de_decouverte_de_fichiers.get_all_specific_paths_under_dir(data_dir, file_extension)
csvs = sorted([x for x in csvs if "/~" not in x ])

# %%
print_cols(csvs)
# Out:
# 0 : /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_COLLECTE.xlsx
# 1 : /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_COLLECTE_analyse.xlsx
# 2 : /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_DELAIS_TX.xlsx
# 3 : /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_DELAIS_TX_analyse.xlsx
# 4 : /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_DOSSIERS.xlsx

# %%
path = csvs[2]  
path
# Out:
# '/Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_DELAIS_TX.xlsx'

# %%
if file_extension.endswith("xlsx"):
    sheetname = input("Quelle feuille ?")
    print("Feuille qui sera analysée : ", sheetname)
# Out:
# Quelle feuille ?BAT_DELAIS_TX
# Feuille qui sera analysée :  BAT_DELAIS_TX

# %% [markdown]
# # 1) Charger la df, compter les lignes et colonnes

# %%
if path.endswith("csv"):
    print("going to read a csv")
    df = pd.read_csv(path, functions_de_decouverte_de_fichiers.find_delimiter(path))
if path.endswith("xlsx"):
    print("going to read an excel file")
    print(path)
    if not sheetname:
        sheetname = input("Which sheetname")
    print(sheetname)
    df = pd.read_excel(path, sheetname=sheetname)
# Out:
# going to read an excel file
# /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_DELAIS_TX.xlsx
# BAT_DELAIS_TX
# /Users/romain/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %% [markdown]
# ## 1.1) taille des données :

# %%
df.shape
# Out:
# (29999, 14)

# %% [markdown]
# ## 1.2) nombre de lignes pleines :

# %%
df.dropna().shape
# Out:
# (13351, 14)

# %% [markdown]
# # 1.3) nombre de nuls par ligne

# %%
to_print = "{col: <15} : {nb_null}"
for i, col in enumerate(sorted(df.columns, key=lambda x:sum(df[x].isnull()), reverse=True)):
    print(i, to_print.format(col=col, nb_null=sum(df[col].isnull())))
# Out:
# 0 DATE SAISINE    : 16253
# 1 ETAB_ITN        : 16053
# 2 ORGANISME       : 15888
# 3 DEMARCHE        : 15767
# 4 DATE DECISION   : 15767
# 5 RESULTAT        : 15767
# 6 ANNEE           : 15767
# 7 MOIS            : 15767
# 8 N° EVT          : 15767
# 9 EVT             : 15767
# 10 RAISON SOCIALE  : 15767
# 11 CONSULTANT      : 15767
# 12 EQUIPE          : 15767
# 13 DELAI           : 0

# %%
df.sample(2).T
# Out:
#                               10785           19409
# DEMARCHE                        TCI             NaN
# DATE DECISION   2018-07-13 00:00:00             NaT
# DATE SAISINE    2016-07-11 00:00:00             NaT
# ORGANISME          TCI DE MARSEILLE             NaN
# RESULTAT                    Positif             NaN
# ANNEE                          2018             NaN
# MOIS                              7             NaN
# N° EVT                  8.48215e+06             NaN
# EVT                         SLIMANI             NaN
# ETAB_ITN                     386639             NaN
# RAISON SOCIALE                ONEPI             NaN
# CONSULTANT                  LEGRAND             NaN
# EQUIPE                    CHEVALLET             NaN
# DELAI                           732  non calculable

# %%
df.tail()
# Out:
#       DEMARCHE DATE DECISION DATE SAISINE ORGANISME RESULTAT  ANNEE  MOIS  \
# 29994      NaN           NaT          NaT       NaN      NaN    NaN   NaN
# 29995      NaN           NaT          NaT       NaN      NaN    NaN   NaN
# 29996      NaN           NaT          NaT       NaN      NaN    NaN   NaN
# 29997      NaN           NaT          NaT       NaN      NaN    NaN   NaN
# 29998      NaN           NaT          NaT       NaN      NaN    NaN   NaN
#
#        N° EVT  EVT  ETAB_ITN RAISON SOCIALE CONSULTANT EQUIPE           DELAI
# 29994     NaN  NaN       NaN            NaN        NaN    NaN  non calculable
# 29995     NaN  NaN       NaN            NaN        NaN    NaN  non calculable
# 29996     NaN  NaN       NaN            NaN        NaN    NaN  non calculable
# 29997     NaN  NaN       NaN            NaN        NaN    NaN  non calculable
# 29998     NaN  NaN       NaN            NaN        NaN    NaN  non calculable

# %% [markdown]
# # 2) on crée un fichier excel qui extrait les top 10 de chaque colonne pour avoir une vue d'ensemble

# %%
def get_filename(path):
    import os
    return os.path.basename(path).split(".")[0]

# %%
import os
analyse_to_excel(df, get_filename(path), os.path.dirname(path))
# Out:
# DEMARCHE
# DATE DECISION
# DATE SAISINE
# ORGANISME
# RESULTAT
# 4
# ANNEE
# MOIS
# N° EVT
# EVT
# 8
# ETAB_ITN
# RAISON SOCIALE
# CONSULTANT
# EQUIPE
# 12
# DELAI
# Wrote into /Users/romain/Google Drive/ayming/BAT_DATAS/BAT_DATAS_DELAIS_TX_analyse.csv

# %% [markdown]
# # 3) En lisant l'excel on peut définir les types de chaque colonne

# %%
index_de_test = df.dropna().sample(2).index
df.ix[index_de_test].T
# Out:
# /Users/romain/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                                 276                  4556
# DEMARCHE                         CRA                 TASS
# DATE DECISION    2017-03-27 00:00:00  2016-09-21 00:00:00
# DATE SAISINE     2016-12-16 00:00:00  2012-09-14 00:00:00
# ORGANISME                    MOSELLE        TASS DU RHONE
# RESULTAT                     Négatif              Positif
# ANNEE                           2017                 2016
# MOIS                               3                    9
# N° EVT                   1.47376e+07          7.14533e+06
# EVT                      JACOB HOLTZ              BELGOUR
# ETAB_ITN                      383328                36180
# RAISON SOCIALE  CORA GMA MUNDOLSHEIM          KEOLIS LYON
# CONSULTANT                GUILLERMIN            LE DUIGOU
# EQUIPE                      KRAWCZYK             KRAWCZYK
# DELAI                            101                 1468

# %%
tmp_df = "temp_df_to_re_read.csv"
df.fillna("", inplace=True)
df.to_csv(tmp_df, index=False)

# %%
print_col_as_dict(df)
# Out:
# dtypes = {
# "DEMARCHE" : str ,
# "DATE DECISION" : str ,
# "DATE SAISINE" : str ,
# "ORGANISME" : str ,
# "RESULTAT" : str ,
# "ANNEE" : str ,
# "MOIS" : str ,
# "N° EVT" : str ,
# "EVT" : str ,
# "ETAB_ITN" : str ,
# "RAISON SOCIALE" : str ,
# "CONSULTANT" : str ,
# "EQUIPE" : str ,
# "DELAI" : str ,
# }
#
# # => changez les types dans les colonnes, et mettez les dates et colonnes de catégories dans les tableaux ci dessous")
# dayfirst = -1
# parse_dates = []
# categories = []
# # rechargez la df avec les colonnes indiquées
# df = pd.read
# df = pd.read_csv(path, sep=sep, dtype=dtypes, parse_dates=parse_dates, dayfrist=dayfirst)
# df.shape, df.dtypes
# # vous pouvez aussi générer du code ensuite pour les colonnes catégorielles
# for col in categories:
# code_for_cat_col(df, col)

# %%
sep
# Out:
# ','

# %%
df = pd.read_csv(tmp_df)
df.dtypes
# Out:
# DEMARCHE           object
# DATE DECISION      object
# DATE SAISINE       object
# ORGANISME          object
# RESULTAT           object
# ANNEE             float64
# MOIS              float64
# N° EVT            float64
# EVT                object
# ETAB_ITN          float64
# RAISON SOCIALE     object
# CONSULTANT         object
# EQUIPE             object
# DELAI              object
# dtype: object

# %%
df.DELAI.replace("non calculable", -1, inplace=True)
# Out:
# 0          35
# 1          77
# 2          55
# 3         471
# 4        1217
# 5         710
# 6         185
# 7        1596
# 8         507
# 9         702
# 10        605
# 11        679
# 12        713
# 13        123
# 14        103
# 15        269
# 16        194
# 17        898
# 18         82
# 19        688
# 20       1307
# 21       1523
# 22        367
# 23       1175
# 24        602
# 25        415
# 26        124
# 27          6
# 28        567
# 29         91
#          ...
# 29969      -1
# 29970      -1
# 29971      -1
# 29972      -1
# 29973      -1
# 29974      -1
# 29975      -1
# 29976      -1
# 29977      -1
# 29978      -1
# 29979      -1
# 29980      -1
# 29981      -1
# 29982      -1
# 29983      -1
# 29984      -1
# 29985      -1
# 29986      -1
# 29987      -1
# 29988      -1
# 29989      -1
# 29990      -1
# 29991      -1
# 29992      -1
# 29993      -1
# 29994      -1
# 29995      -1
# 29996      -1
# 29997      -1
# 29998      -1
# Name: DELAI, Length: 29999, dtype: object

# %%
dtypes = {
"DEMARCHE" : str ,
"DATE DECISION" : str ,
"DATE SAISINE" : str ,
"ORGANISME" : str ,
"RESULTAT" : str ,
"ANNEE" : float ,
"MOIS" : float ,
"N° EVT" : str ,
"EVT" : str ,
"ETAB_ITN" : str ,
"RAISON SOCIALE" : str ,
"CONSULTANT" : str ,
"EQUIPE" : str ,
"DELAI" : int ,
}

# => changez les types dans les colonnes, et mettez les dates et colonnes de catégories dans les tableaux ci dessous")
dayfirst = -1
parse_dates = ["DATE DECISION", "DATE SAISINE", ]
parse_dates = [1, 2]
categories = ["RESULTAT"]
# rechargez la df avec les colonnes indiquées
df = pd.read_csv(tmp_df, sep=sep, dtype=dtypes, parse_dates=parse_dates, dayfirst=dayfirst)
df.shape, df.dtypes
# vous pouvez aussi générer du code ensuite pour les colonnes catégorielles
for col in categories:
    code_for_cat_col(df, col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array from dtype('O') to dtype('int64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-347-2fb1c6811c27> in <module>()
#      22 categories = ["RESULTAT"]
#      23 # rechargez la df avec les colonnes indiquées
# ---> 24 df = pd.read_csv(tmp_df, sep=sep, dtype=dtypes, parse_dates=parse_dates, dayfirst=dayfirst)
#      25 df.shape, df.dtypes
#      26 # vous pouvez aussi générer du code ensuite pour les colonnes catégorielles
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: invalid literal for int() with base 10: 'non calculable'

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# EQUIPE                 object
# CONSULTANT             object
# N° DEP                 object
# TYPE DEP               object
# n° EVT                 object
# EVT                    object
# DATE EVT       datetime64[ns]
# TYPE EVT               object
# COMMENT EVT            object
# CE                     object
# TX IPP                float64
# NB IJ                 float64
# ETAB_RS                object
# ETAB_ITN               object
# ETAB_VILLE             object
# ETAB_SIRET             object
# ETAB_GRP               object
# DT_CREATION    datetime64[ns]
# ANNEE CREA            float64
# MOIS CREA             float64
# TRANCHE                object
# dtype: object

# %% [markdown]
# # On peut vérifier la cohérence entre les nouvelles data formatées et le print ci dessus

# %%
df.ix[index_de_test].T
# Out:
# /Users/romain/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                                          9894   \
# Unnamed: 0                                                9894
# EQUIPE                                                KRAWCZYK
# CONSULTANT                                             MICHAUT
# N° DEP                                              15426935.0
# TYPE DEP                                                   1.0
# n° EVT                                              15426933.0
# EVT                                                      LOYER
# DATE EVT                                   2016-09-20 00:00:00
# TYPE EVT                                                  MP30
# COMMENT EVT  PAS D'enjeux pour le moment car pas d'arrêt sa...
# CE                                                      2016.0
# TX IPP                                                       0
# NB IJ                                                        0
# ETAB_RS                                                    AFC
# ETAB_ITN                                                6658.0
# ETAB_VILLE                                         REDON CEDEX
# ETAB_SIRET                                    30647367900018.0
# ETAB_GRP                                    FAMILLE GROSDIDIER
# DT_CREATION                                2017-04-10 17:00:26
# ANNEE CREA                                                2017
# MOIS CREA                                                    4
# TRANCHE                                                    IT1
#
#                                                   19313
# Unnamed: 0                                        19313
# EQUIPE                                        BEN TAHAR
# CONSULTANT                                       SZUMNY
# N° DEP                                       16085799.0
# TYPE DEP                                            1.0
# n° EVT                                       16085797.0
# EVT                                             BELARBI
# DATE EVT                            2016-04-15 00:00:00
# TYPE EVT                                             AT
# COMMENT EVT  rechute du 11/08/17 mais conso le 08/07/17
# CE                                               2016.0
# TX IPP                                                0
# NB IJ                                               191
# ETAB_RS                                        BRICOMAN
# ETAB_ITN                                       416047.0
# ETAB_VILLE                                     MASSIEUX
# ETAB_SIRET                             42080992300196.0
# ETAB_GRP      TETE DE PONT OPERATIONNELLE GROUPE AUCHAN
# DT_CREATION                         2017-11-15 15:33:12
# ANNEE CREA                                         2017
# MOIS CREA                                            11
# TRANCHE                                             IT6

# %% [markdown]
# # 4) gestion des colonnes catégorielles

# %%
categories = ["TRANCHE"]

# %%
from pandas.api.types import CategoricalDtype
for col in categories:
    code_for_cat_col(df, col)
# Copiez le code ci dessous dans des cellules pour les exécuter
# Out:
# from pandas.api.types import CategoricalDtype
# cat = CategoricalDtype(categories=['AUTRES','IP INDEFINI','IP1','IP2','IP3','IP4','IT INDEFINI','IT1','IT2','IT3','IT4','IT5','IT6',], ordered=True)
# #df['TRANCHE'] = df['TRANCHE'].astype(cat)

# %%
cat = CategoricalDtype(categories=['IP1','IP2','IP3','IP4','IP INDEFINI','IT INDEFINI','IT1','IT2','IT3','IT4','IT5','IT6','AUTRES',], ordered=True)
df['TRANCHE'] = df['TRANCHE'].astype(cat)

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# EQUIPE                 object
# CONSULTANT             object
# N° DEP                 object
# TYPE DEP               object
# n° EVT                 object
# EVT                    object
# DATE EVT       datetime64[ns]
# TYPE EVT               object
# COMMENT EVT            object
# CE                     object
# TX IPP                float64
# NB IJ                 float64
# ETAB_RS                object
# ETAB_ITN               object
# ETAB_VILLE             object
# ETAB_SIRET             object
# ETAB_GRP               object
# DT_CREATION    datetime64[ns]
# ANNEE CREA            float64
# MOIS CREA             float64
# TRANCHE              category
# dtype: object

# %% [markdown]
# # 7) on crée des colonnes de jours / semaines sur les dates

# %%
def decompose_date(df, analyse_col):
    print(analyse_col)
    import pandas as pd
    clean_col = analyse_col.replace(" ", "_")
    from collections import OrderedDict
    weekdays = OrderedDict(
        {0: "lundi", 1: "mardi", 2: "mercredi", 3: "jeudi", 4: "vendredi", 5: "samedi", 6: "dimanche"})
    mois = OrderedDict({1: "janvier", 2: "février", 3: "mars", 4: "avril", 5: "mai", 6: "juin", 7: "juillet", 8: "août",
                        9: "septembre", 10: "octobre", 11: "novembre", 12: "décembre"})
    #
    new_col = "%s_jour_semaine" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: x.weekday()).map(weekdays)
    df[new_col] = pd.Categorical(df[new_col], categories=weekdays.values(), ordered=True)
    #
    new_col = "%s_jour_semaine_int" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: x.weekday())

    #
    new_col = "%s_jour_mois" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: x.day)
    df[new_col] = pd.Categorical(df[new_col], categories=range(32), ordered=True)

    #
    new_col = "%s_mois" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: x.month).map(mois)
    df[new_col] = pd.Categorical(df[new_col], categories=mois.values(), ordered=True)
    #
    new_col = "%s_nth_mois" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: x.month)
    df[new_col] = pd.Categorical(df[new_col], categories=range(1, 13), ordered=True)
    #
    new_col = "%s_week" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: int(x.week))
    df[new_col] = pd.Categorical(df[new_col], categories=range(53), ordered=True)

    #
    new_col = "%s_year" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: int(x.year))
    df[new_col] = pd.Categorical(df[new_col], categories=sorted(list(df[new_col].unique())), ordered=True)
    #
    new_col = "%s_nth_day" % clean_col
    df[new_col] = df[analyse_col].map(lambda x: x.timetuple().tm_yday)
    df[new_col] = pd.Categorical(df[new_col], categories=range(366), ordered=True)
    print("fini")

# %%
from collections import OrderedDict

# %%
weekdays = OrderedDict({0: "lundi", 1:"mardi", 2:"mercredi", 3:"jeudi", 4:"vendredi", 5:"samedi", 6:"dimanche"})
mois     = OrderedDict({1:"janvier", 2:"février", 3:"mars", 4:"avril", 5: "mai", 6:"juin", 7:"juillet", 8:"août", 9:"septembre", 10:"octobre", 11:"novembre", 12:"décembre"})

# %%
#parse_dates = {"Created on" : "%d.%m.%Y", 
#               "Follow Up Date" : "%d.%m.%Y", 
#               "Invoice expect. date (QMT)" : "%d.%m.%Y"}
parse_dates
# Out:
# ['DATE EVT', 'DT_CREATION']

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# EQUIPE                 object
# CONSULTANT             object
# N° DEP                 object
# TYPE DEP               object
# n° EVT                 object
# EVT                    object
# DATE EVT       datetime64[ns]
# TYPE EVT               object
# COMMENT EVT            object
# CE                     object
# TX IPP                float64
# NB IJ                 float64
# ETAB_RS                object
# ETAB_ITN               object
# ETAB_VILLE             object
# ETAB_SIRET             object
# ETAB_GRP               object
# DT_CREATION    datetime64[ns]
# ANNEE CREA            float64
# MOIS CREA             float64
# TRANCHE              category
# dtype: object

# %%
for col_date in parse_dates:
    df[col_date] = df[col_date].fillna(datetime.date(1970,1,1))
    decompose_date(df, col_date)
df.dtypes
# Out:
# DATE EVT
# fini
# DT_CREATION
# fini
# Unnamed: 0                               int64
# EQUIPE                                  object
# CONSULTANT                              object
# N° DEP                                  object
# TYPE DEP                                object
# n° EVT                                  object
# EVT                                     object
# DATE EVT                        datetime64[ns]
# TYPE EVT                                object
# COMMENT EVT                             object
# CE                                      object
# TX IPP                                 float64
# NB IJ                                  float64
# ETAB_RS                                 object
# ETAB_ITN                                object
# ETAB_VILLE                              object
# ETAB_SIRET                              object
# ETAB_GRP                                object
# DT_CREATION                     datetime64[ns]
# ANNEE CREA                             float64
# MOIS CREA                              float64
# TRANCHE                               category
# DATE_EVT_jour_semaine                 category
# DATE_EVT_jour_semaine_int                int64
# DATE_EVT_jour_mois                    category
# DATE_EVT_mois                         category
# DATE_EVT_nth_mois                     category
# DATE_EVT_week                         category
# DATE_EVT_year                         category
# DATE_EVT_nth_day                      category
# DT_CREATION_jour_semaine              category
# DT_CREATION_jour_semaine_int             int64
# DT_CREATION_jour_mois                 category
# DT_CREATION_mois                      category
# DT_CREATION_nth_mois                  category
# DT_CREATION_week                      category
# DT_CREATION_year                      category
# DT_CREATION_nth_day                   category
# dtype: object

# %% [markdown]
# # on split les valeurs en eur pour récupérer les montants

# %%
def fetch_devise(string):
    """
    cherche les mots ["EUR", "$", "£"] dans la string et le renvoie si trouvé.
    """
    devises = ["EUR", "$", "£"]
    default = "unknown"
    for devise in devises:
        if devise in string:
            return devise
    return default
def fetch_value(string):
    """
    Cherche les nombres dans la string.
    """
    import re
    regex = re.compile("\d+(?:\.\d+)*")
    return regex.findall(string)

# %%
#df["devise"] = df['Expected Sales Vol.'].map(fetch_devise)

# %%
import re
regex = re.compile("\d+(?:\.\d+)*")

# %%
#df["montant"] = df['Expected Sales Vol.'].map(regex.findall).map(lambda x: int(x[0].replace(".", "")))

# %% [markdown]
# # 6) Ici on doit avoir une df propre

# %%
df.T
# Out:
#                                                             0      \
# Unnamed: 0                                                      0
# EQUIPE                                                        TOU
# CONSULTANT                                                 HOULLE
# N° DEP                                                 12198796.0
# TYPE DEP                                                      1.0
# n° EVT                                                  9993501.0
# EVT                                                         LUCAS
# DATE EVT                                      2009-07-01 00:00:00
# TYPE EVT                                                       MP
# COMMENT EVT                                                   NaN
# CE                                                         2016.0
# TX IPP                                                        NaN
# NB IJ                                                         NaN
# ETAB_RS                                                   VATEDIS
# ETAB_ITN                                                 441255.0
# ETAB_VILLE                                    ST NICOLAS DU PELEM
# ETAB_SIRET                                       50393275800025.0
# ETAB_GRP                      TETE DE PONT OPERATIONNELLE TERRENA
# DT_CREATION                                   2014-10-14 17:18:02
# ANNEE CREA                                                   2014
# MOIS CREA                                                      10
# TRANCHE                                               IT INDEFINI
# DATE_EVT_jour_semaine                                    mercredi
# DATE_EVT_jour_semaine_int                                       2
# DATE_EVT_jour_mois                                              1
# DATE_EVT_mois                                             juillet
# DATE_EVT_nth_mois                                               7
# DATE_EVT_week                                                  27
# DATE_EVT_year                                                2009
# DATE_EVT_nth_day                                              182
# DT_CREATION_jour_semaine                                    mardi
# DT_CREATION_jour_semaine_int                                    1
# DT_CREATION_jour_mois                                          14
# DT_CREATION_mois                                          octobre
# DT_CREATION_nth_mois                                           10
# DT_CREATION_week                                               42
# DT_CREATION_year                                             2014
# DT_CREATION_nth_day                                           287
#
#                                                          1      \
# Unnamed: 0                                                   1
# EQUIPE                                                  MAUREL
# CONSULTANT                                         EYEBE EYEBE
# N° DEP                                              13145614.0
# TYPE DEP                                                   3.0
# n° EVT                                              12869426.0
# EVT                                             CHAIAHELOUDJOU
# DATE EVT                                   2014-10-28 00:00:00
# TYPE EVT                                                  MP65
# COMMENT EVT                         Pas de motif de compte spé
# CE                                                      2016.0
# TX IPP                                                       3
# NB IJ                                                      NaN
# ETAB_RS                                          ONET SERVICES
# ETAB_ITN                                              430084.0
# ETAB_VILLE                                           MARSEILLE
# ETAB_SIRET                                     6780042503780.0
# ETAB_GRP                      TETE DE PONT OPERATIONNELLE ONET
# DT_CREATION                                2015-09-09 09:43:09
# ANNEE CREA                                                2015
# MOIS CREA                                                    9
# TRANCHE                                                    IP1
# DATE_EVT_jour_semaine                                    mardi
# DATE_EVT_jour_semaine_int                                    1
# DATE_EVT_jour_mois                                          28
# DATE_EVT_mois                                          octobre
# DATE_EVT_nth_mois                                           10
# DATE_EVT_week                                               44
# DATE_EVT_year                                             2014
# DATE_EVT_nth_day                                           301
# DT_CREATION_jour_semaine                              mercredi
# DT_CREATION_jour_semaine_int                                 2
# DT_CREATION_jour_mois                                        9
# DT_CREATION_mois                                     septembre
# DT_CREATION_nth_mois                                         9
# DT_CREATION_week                                            37
# DT_CREATION_year                                          2015
# DT_CREATION_nth_day                                        252
#
#                                             2      \
# Unnamed: 0                                      2
# EQUIPE                                   CARRILLO
# CONSULTANT                                JANNING
# N° DEP                                 13297342.0
# TYPE DEP                                      1.0
# n° EVT                                 13297340.0
# EVT                                       SOUFANE
# DATE EVT                      2016-06-25 00:00:00
# TYPE EVT                                       AT
# COMMENT EVT                                   NaN
# CE                                         2016.0
# TX IPP                                        NaN
# NB IJ                                         187
# ETAB_RS                                   ERGALIS
# ETAB_ITN                                 918277.0
# ETAB_VILLE                                  CERGY
# ETAB_SIRET                       72204562201021.0
# ETAB_GRP                                    FLFPE
# DT_CREATION                   2015-11-16 14:37:10
# ANNEE CREA                                   2015
# MOIS CREA                                      11
# TRANCHE                                       IT6
# DATE_EVT_jour_semaine                      samedi
# DATE_EVT_jour_semaine_int                       5
# DATE_EVT_jour_mois                             25
# DATE_EVT_mois                                juin
# DATE_EVT_nth_mois                               6
# DATE_EVT_week                                  25
# DATE_EVT_year                                2016
# DATE_EVT_nth_day                              177
# DT_CREATION_jour_semaine                    lundi
# DT_CREATION_jour_semaine_int                    0
# DT_CREATION_jour_mois                          16
# DT_CREATION_mois                         novembre
# DT_CREATION_nth_mois                           11
# DT_CREATION_week                               47
# DT_CREATION_year                             2015
# DT_CREATION_nth_day                           320
#
#                                                        3      \
# Unnamed: 0                                                 3
# EQUIPE                                                   TOU
# CONSULTANT                                            HOULLE
# N° DEP                                            13406351.0
# TYPE DEP                                                 3.0
# n° EVT                                            11152687.0
# EVT                                                FONTELLES
# DATE EVT                                 2013-03-16 00:00:00
# TYPE EVT                                                  MP
# COMMENT EVT                                              NaN
# CE                                                    2016.0
# TX IPP                                                    31
# NB IJ                                                    NaN
# ETAB_RS                                   EUROVIANDE SERVICE
# ETAB_ITN                                            210039.0
# ETAB_VILLE                          ST SYLVAIN D ANJOU CEDEX
# ETAB_SIRET                                  30938306500062.0
# ETAB_GRP                      TETE DE PONT OPERATIONNELLE CS
# DT_CREATION                              2016-01-11 09:25:34
# ANNEE CREA                                              2016
# MOIS CREA                                                  1
# TRANCHE                                                  IP3
# DATE_EVT_jour_semaine                                 samedi
# DATE_EVT_jour_semaine_int                                  5
# DATE_EVT_jour_mois                                        16
# DATE_EVT_mois                                           mars
# DATE_EVT_nth_mois                                          3
# DATE_EVT_week                                             11
# DATE_EVT_year                                           2013
# DATE_EVT_nth_day                                          75
# DT_CREATION_jour_semaine                               lundi
# DT_CREATION_jour_semaine_int                               0
# DT_CREATION_jour_mois                                     11
# DT_CREATION_mois                                     janvier
# DT_CREATION_nth_mois                                       1
# DT_CREATION_week                                           2
# DT_CREATION_year                                        2016
# DT_CREATION_nth_day                                       11
#
#                                                                           4      \
# Unnamed: 0                                                                    4
# EQUIPE                                                                BEN TAHAR
# CONSULTANT                                                              DOMPERT
# N° DEP                                                               13408421.0
# TYPE DEP                                                                    3.0
# n° EVT                                                               13256242.0
# EVT                                                                        DANG
# DATE EVT                                                    2014-06-19 00:00:00
# TYPE EVT                                                                   MP57
# COMMENT EVT                   MP n° 140619446 : rupture de la coiffe des rot...
# CE                                                                       2016.0
# TX IPP                                                                        2
# NB IJ                                                                       NaN
# ETAB_RS                                     LACTALIS NESTLE ULTRA FRAIS MARQUES
# ETAB_ITN                                                                47388.0
# ETAB_VILLE                                                               VALLET
# ETAB_SIRET                                                     35006338400043.0
# ETAB_GRP                        TETE DE PONT OPERATIONNELLE BSA GROUPE LACTALIS
# DT_CREATION                                                 2016-01-11 16:26:27
# ANNEE CREA                                                                 2016
# MOIS CREA                                                                     1
# TRANCHE                                                                     IP1
# DATE_EVT_jour_semaine                                                     jeudi
# DATE_EVT_jour_semaine_int                                                     3
# DATE_EVT_jour_mois                                                           19
# DATE_EVT_mois                                                              juin
# DATE_EVT_nth_mois                                                             6
# DATE_EVT_week                                                                25
# DATE_EVT_year                                                              2014
# DATE_EVT_nth_day                                                            170
# DT_CREATION_jour_semaine                                                  lundi
# DT_CREATION_jour_semaine_int                                                  0
# DT_CREATION_jour_mois                                                        11
# DT_CREATION_mois                                                        janvier
# DT_CREATION_nth_mois                                                          1
# DT_CREATION_week                                                              2
# DT_CREATION_year                                                           2016
# DT_CREATION_nth_day                                                          11
#
#                                                                           5      \
# Unnamed: 0                                                                    5
# EQUIPE                                                                 CARRILLO
# CONSULTANT                                                               ZERROU
# N° DEP                                                               13410004.0
# TYPE DEP                                                                    1.0
# n° EVT                                                               13410002.0
# EVT                                                                       SICRE
# DATE EVT                                                    1970-01-01 00:00:00
# TYPE EVT                                                                     AT
# COMMENT EVT                                                                 NaN
# CE                                                                       2016.0
# TX IPP                                                                      NaN
# NB IJ                                                                       NaN
# ETAB_RS                                                        CASTORAMA FRANCE
# ETAB_ITN                                                               957479.0
# ETAB_VILLE                                                           PIERRELAYE
# ETAB_SIRET                                                     45167897301713.0
# ETAB_GRP                      TETE DE PONT OPERATIONNELLE CASTORAMA DUBOIS I...
# DT_CREATION                                                 2016-01-12 09:07:13
# ANNEE CREA                                                                 2016
# MOIS CREA                                                                     1
# TRANCHE                                                             IT INDEFINI
# DATE_EVT_jour_semaine                                                     jeudi
# DATE_EVT_jour_semaine_int                                                     3
# DATE_EVT_jour_mois                                                            1
# DATE_EVT_mois                                                           janvier
# DATE_EVT_nth_mois                                                             1
# DATE_EVT_week                                                                 1
# DATE_EVT_year                                                              1970
# DATE_EVT_nth_day                                                              1
# DT_CREATION_jour_semaine                                                  mardi
# DT_CREATION_jour_semaine_int                                                  1
# DT_CREATION_jour_mois                                                        12
# DT_CREATION_mois                                                        janvier
# DT_CREATION_nth_mois                                                          1
# DT_CREATION_week                                                              2
# DT_CREATION_year                                                           2016
# DT_CREATION_nth_day                                                          12
#
#                                                                           6      \
# Unnamed: 0                                                                    6
# EQUIPE                                                                   REFFAY
# CONSULTANT                                                               BUIZZA
# N° DEP                                                               13417552.0
# TYPE DEP                                                                    3.0
# n° EVT                                                               13417543.0
# EVT                                                                       DAVID
# DATE EVT                                                    2014-10-23 00:00:00
# TYPE EVT                                                                     AT
# COMMENT EVT                   établissement a priori fermé - attendre confir...
# CE                                                                       2016.0
# TX IPP                                                                       10
# NB IJ                                                                       NaN
# ETAB_RS                                                                 RAS 180
# ETAB_ITN                                                               456882.0
# ETAB_VILLE                                                              VALENCE
# ETAB_SIRET                                                     53540937900026.0
# ETAB_GRP                                                                    RAS
# DT_CREATION                                                 2016-01-13 14:58:28
# ANNEE CREA                                                                 2016
# MOIS CREA                                                                     1
# TRANCHE                                                                     IP2
# DATE_EVT_jour_semaine                                                     jeudi
# DATE_EVT_jour_semaine_int                                                     3
# DATE_EVT_jour_mois                                                           23
# DATE_EVT_mois                                                           octobre
# DATE_EVT_nth_mois                                                            10
# DATE_EVT_week                                                                43
# DATE_EVT_year                                                              2014
# DATE_EVT_nth_day                                                            296
# DT_CREATION_jour_semaine                                               mercredi
# DT_CREATION_jour_semaine_int                                                  2
# DT_CREATION_jour_mois                                                        13
# DT_CREATION_mois                                                        janvier
# DT_CREATION_nth_mois                                                          1
# DT_CREATION_week                                                              2
# DT_CREATION_year                                                           2016
# DT_CREATION_nth_day                                                          13
#
#                                                                   7      \
# Unnamed: 0                                                            7
# EQUIPE                                                            DEVIN
# CONSULTANT                                                    COUTURIER
# N° DEP                                                       13423791.0
# TYPE DEP                                                            3.0
# n° EVT                                                       12303981.0
# EVT                                                          DA FONSECA
# DATE EVT                                            2014-03-22 00:00:00
# TYPE EVT                                                           MP57
# COMMENT EVT                                                         NaN
# CE                                                               2016.0
# TX IPP                                                                5
# NB IJ                                                               NaN
# ETAB_RS                       SAVAC SERVICE AUTOMOBILE VALLEE CHEVREUSE
# ETAB_ITN                                                        45280.0
# ETAB_VILLE                                                    CHEVREUSE
# ETAB_SIRET                                             67980160500016.0
# ETAB_GRP                              AUTOCARS DE CHEVREUSE ET ASSOCIES
# DT_CREATION                                         2016-01-14 15:10:00
# ANNEE CREA                                                         2016
# MOIS CREA                                                             1
# TRANCHE                                                             IP1
# DATE_EVT_jour_semaine                                            samedi
# DATE_EVT_jour_semaine_int                                             5
# DATE_EVT_jour_mois                                                   22
# DATE_EVT_mois                                                      mars
# DATE_EVT_nth_mois                                                     3
# DATE_EVT_week                                                        12
# DATE_EVT_year                                                      2014
# DATE_EVT_nth_day                                                     81
# DT_CREATION_jour_semaine                                          jeudi
# DT_CREATION_jour_semaine_int                                          3
# DT_CREATION_jour_mois                                                14
# DT_CREATION_mois                                                janvier
# DT_CREATION_nth_mois                                                  1
# DT_CREATION_week                                                      2
# DT_CREATION_year                                                   2016
# DT_CREATION_nth_day                                                  14
#
#                                             8                        9      \
# Unnamed: 0                                      8                        9
# EQUIPE                                     CERNAY                BEN TAHAR
# CONSULTANT                              GUILLAUME                 LESPINET
# N° DEP                                 13424749.0               13429238.0
# TYPE DEP                                      3.0                      3.0
# n° EVT                                 13424743.0               13429232.0
# EVT                                     JOUANNEST                  WOZNIAK
# DATE EVT                      2014-11-25 00:00:00      2015-05-21 00:00:00
# TYPE EVT                                       AT                       MP
# COMMENT EVT                                   NaN             Procédure FI
# CE                                         2016.0                   2016.0
# TX IPP                                         10                       70
# NB IJ                                         NaN                      NaN
# ETAB_RS                        FRANCE TELEVISIONS       BRIDGESTONE FRANCE
# ETAB_ITN                                 227524.0                  12611.0
# ETAB_VILLE                              MARSEILLE            BETHUNE CEDEX
# ETAB_SIRET                       43276694700449.0         36120038900019.0
# ETAB_GRP                       FRANCE TELEVISIONS  BRIDGESTONE CORPORATION
# DT_CREATION                   2016-01-14 17:11:02      2016-01-15 17:07:06
# ANNEE CREA                                   2016                     2016
# MOIS CREA                                       1                        1
# TRANCHE                                       IP2                      IP4
# DATE_EVT_jour_semaine                       mardi                    jeudi
# DATE_EVT_jour_semaine_int                       1                        3
# DATE_EVT_jour_mois                             25                       21
# DATE_EVT_mois                            novembre                      mai
# DATE_EVT_nth_mois                              11                        5
# DATE_EVT_week                                  48                       21
# DATE_EVT_year                                2014                     2015
# DATE_EVT_nth_day                              329                      141
# DT_CREATION_jour_semaine                    jeudi                 vendredi
# DT_CREATION_jour_semaine_int                    3                        4
# DT_CREATION_jour_mois                          14                       15
# DT_CREATION_mois                          janvier                  janvier
# DT_CREATION_nth_mois                            1                        1
# DT_CREATION_week                                2                        2
# DT_CREATION_year                             2016                     2016
# DT_CREATION_nth_day                            14                       15
#
#                                      ...                         49989  \
# Unnamed: 0                           ...                         49989
# EQUIPE                               ...                           NaN
# CONSULTANT                           ...                           NaN
# N° DEP                               ...                           NaN
# TYPE DEP                             ...                           NaN
# n° EVT                               ...                           NaN
# EVT                                  ...                           NaN
# DATE EVT                             ...           1970-01-01 00:00:00
# TYPE EVT                             ...                           NaN
# COMMENT EVT                          ...                           NaN
# CE                                   ...                           NaN
# TX IPP                               ...                           NaN
# NB IJ                                ...                           NaN
# ETAB_RS                              ...                           NaN
# ETAB_ITN                             ...                           NaN
# ETAB_VILLE                           ...                           NaN
# ETAB_SIRET                           ...                           NaN
# ETAB_GRP                             ...                           NaN
# DT_CREATION                          ...           1970-01-01 00:00:00
# ANNEE CREA                           ...                           NaN
# MOIS CREA                            ...                           NaN
# TRANCHE                              ...                        AUTRES
# DATE_EVT_jour_semaine                ...                         jeudi
# DATE_EVT_jour_semaine_int            ...                             3
# DATE_EVT_jour_mois                   ...                             1
# DATE_EVT_mois                        ...                       janvier
# DATE_EVT_nth_mois                    ...                             1
# DATE_EVT_week                        ...                             1
# DATE_EVT_year                        ...                          1970
# DATE_EVT_nth_day                     ...                             1
# DT_CREATION_jour_semaine             ...                         jeudi
# DT_CREATION_jour_semaine_int         ...                             3
# DT_CREATION_jour_mois                ...                             1
# DT_CREATION_mois                     ...                       janvier
# DT_CREATION_nth_mois                 ...                             1
# DT_CREATION_week                     ...                             1
# DT_CREATION_year                     ...                          1970
# DT_CREATION_nth_day                  ...                             1
#
#                                             49990                49991  \
# Unnamed: 0                                  49990                49991
# EQUIPE                                        NaN                  NaN
# CONSULTANT                                    NaN                  NaN
# N° DEP                                        NaN                  NaN
# TYPE DEP                                      NaN                  NaN
# n° EVT                                        NaN                  NaN
# EVT                                           NaN                  NaN
# DATE EVT                      1970-01-01 00:00:00  1970-01-01 00:00:00
# TYPE EVT                                      NaN                  NaN
# COMMENT EVT                                   NaN                  NaN
# CE                                            NaN                  NaN
# TX IPP                                        NaN                  NaN
# NB IJ                                         NaN                  NaN
# ETAB_RS                                       NaN                  NaN
# ETAB_ITN                                      NaN                  NaN
# ETAB_VILLE                                    NaN                  NaN
# ETAB_SIRET                                    NaN                  NaN
# ETAB_GRP                                      NaN                  NaN
# DT_CREATION                   1970-01-01 00:00:00  1970-01-01 00:00:00
# ANNEE CREA                                    NaN                  NaN
# MOIS CREA                                     NaN                  NaN
# TRANCHE                                    AUTRES               AUTRES
# DATE_EVT_jour_semaine                       jeudi                jeudi
# DATE_EVT_jour_semaine_int                       3                    3
# DATE_EVT_jour_mois                              1                    1
# DATE_EVT_mois                             janvier              janvier
# DATE_EVT_nth_mois                               1                    1
# DATE_EVT_week                                   1                    1
# DATE_EVT_year                                1970                 1970
# DATE_EVT_nth_day                                1                    1
# DT_CREATION_jour_semaine                    jeudi                jeudi
# DT_CREATION_jour_semaine_int                    3                    3
# DT_CREATION_jour_mois                           1                    1
# DT_CREATION_mois                          janvier              janvier
# DT_CREATION_nth_mois                            1                    1
# DT_CREATION_week                                1                    1
# DT_CREATION_year                             1970                 1970
# DT_CREATION_nth_day                             1                    1
#
#                                             49992                49993  \
# Unnamed: 0                                  49992                49993
# EQUIPE                                        NaN                  NaN
# CONSULTANT                                    NaN                  NaN
# N° DEP                                        NaN                  NaN
# TYPE DEP                                      NaN                  NaN
# n° EVT                                        NaN                  NaN
# EVT                                           NaN                  NaN
# DATE EVT                      1970-01-01 00:00:00  1970-01-01 00:00:00
# TYPE EVT                                      NaN                  NaN
# COMMENT EVT                                   NaN                  NaN
# CE                                            NaN                  NaN
# TX IPP                                        NaN                  NaN
# NB IJ                                         NaN                  NaN
# ETAB_RS                                       NaN                  NaN
# ETAB_ITN                                      NaN                  NaN
# ETAB_VILLE                                    NaN                  NaN
# ETAB_SIRET                                    NaN                  NaN
# ETAB_GRP                                      NaN                  NaN
# DT_CREATION                   1970-01-01 00:00:00  1970-01-01 00:00:00
# ANNEE CREA                                    NaN                  NaN
# MOIS CREA                                     NaN                  NaN
# TRANCHE                                    AUTRES               AUTRES
# DATE_EVT_jour_semaine                       jeudi                jeudi
# DATE_EVT_jour_semaine_int                       3                    3
# DATE_EVT_jour_mois                              1                    1
# DATE_EVT_mois                             janvier              janvier
# DATE_EVT_nth_mois                               1                    1
# DATE_EVT_week                                   1                    1
# DATE_EVT_year                                1970                 1970
# DATE_EVT_nth_day                                1                    1
# DT_CREATION_jour_semaine                    jeudi                jeudi
# DT_CREATION_jour_semaine_int                    3                    3
# DT_CREATION_jour_mois                           1                    1
# DT_CREATION_mois                          janvier              janvier
# DT_CREATION_nth_mois                            1                    1
# DT_CREATION_week                                1                    1
# DT_CREATION_year                             1970                 1970
# DT_CREATION_nth_day                             1                    1
#
#                                             49994                49995  \
# Unnamed: 0                                  49994                49995
# EQUIPE                                        NaN                  NaN
# CONSULTANT                                    NaN                  NaN
# N° DEP                                        NaN                  NaN
# TYPE DEP                                      NaN                  NaN
# n° EVT                                        NaN                  NaN
# EVT                                           NaN                  NaN
# DATE EVT                      1970-01-01 00:00:00  1970-01-01 00:00:00
# TYPE EVT                                      NaN                  NaN
# COMMENT EVT                                   NaN                  NaN
# CE                                            NaN                  NaN
# TX IPP                                        NaN                  NaN
# NB IJ                                         NaN                  NaN
# ETAB_RS                                       NaN                  NaN
# ETAB_ITN                                      NaN                  NaN
# ETAB_VILLE                                    NaN                  NaN
# ETAB_SIRET                                    NaN                  NaN
# ETAB_GRP                                      NaN                  NaN
# DT_CREATION                   1970-01-01 00:00:00  1970-01-01 00:00:00
# ANNEE CREA                                    NaN                  NaN
# MOIS CREA                                     NaN                  NaN
# TRANCHE                                    AUTRES               AUTRES
# DATE_EVT_jour_semaine                       jeudi                jeudi
# DATE_EVT_jour_semaine_int                       3                    3
# DATE_EVT_jour_mois                              1                    1
# DATE_EVT_mois                             janvier              janvier
# DATE_EVT_nth_mois                               1                    1
# DATE_EVT_week                                   1                    1
# DATE_EVT_year                                1970                 1970
# DATE_EVT_nth_day                                1                    1
# DT_CREATION_jour_semaine                    jeudi                jeudi
# DT_CREATION_jour_semaine_int                    3                    3
# DT_CREATION_jour_mois                           1                    1
# DT_CREATION_mois                          janvier              janvier
# DT_CREATION_nth_mois                            1                    1
# DT_CREATION_week                                1                    1
# DT_CREATION_year                             1970                 1970
# DT_CREATION_nth_day                             1                    1
#
#                                             49996                49997  \
# Unnamed: 0                                  49996                49997
# EQUIPE                                        NaN                  NaN
# CONSULTANT                                    NaN                  NaN
# N° DEP                                        NaN                  NaN
# TYPE DEP                                      NaN                  NaN
# n° EVT                                        NaN                  NaN
# EVT                                           NaN                  NaN
# DATE EVT                      1970-01-01 00:00:00  1970-01-01 00:00:00
# TYPE EVT                                      NaN                  NaN
# COMMENT EVT                                   NaN                  NaN
# CE                                            NaN                  NaN
# TX IPP                                        NaN                  NaN
# NB IJ                                         NaN                  NaN
# ETAB_RS                                       NaN                  NaN
# ETAB_ITN                                      NaN                  NaN
# ETAB_VILLE                                    NaN                  NaN
# ETAB_SIRET                                    NaN                  NaN
# ETAB_GRP                                      NaN                  NaN
# DT_CREATION                   1970-01-01 00:00:00  1970-01-01 00:00:00
# ANNEE CREA                                    NaN                  NaN
# MOIS CREA                                     NaN                  NaN
# TRANCHE                                    AUTRES               AUTRES
# DATE_EVT_jour_semaine                       jeudi                jeudi
# DATE_EVT_jour_semaine_int                       3                    3
# DATE_EVT_jour_mois                              1                    1
# DATE_EVT_mois                             janvier              janvier
# DATE_EVT_nth_mois                               1                    1
# DATE_EVT_week                                   1                    1
# DATE_EVT_year                                1970                 1970
# DATE_EVT_nth_day                                1                    1
# DT_CREATION_jour_semaine                    jeudi                jeudi
# DT_CREATION_jour_semaine_int                    3                    3
# DT_CREATION_jour_mois                           1                    1
# DT_CREATION_mois                          janvier              janvier
# DT_CREATION_nth_mois                            1                    1
# DT_CREATION_week                                1                    1
# DT_CREATION_year                             1970                 1970
# DT_CREATION_nth_day                             1                    1
#
#                                             49998
# Unnamed: 0                                  49998
# EQUIPE                                        NaN
# CONSULTANT                                    NaN
# N° DEP                                        NaN
# TYPE DEP                                      NaN
# n° EVT                                        NaN
# EVT                                           NaN
# DATE EVT                      1970-01-01 00:00:00
# TYPE EVT                                      NaN
# COMMENT EVT                                   NaN
# CE                                            NaN
# TX IPP                                        NaN
# NB IJ                                         NaN
# ETAB_RS                                       NaN
# ETAB_ITN                                      NaN
# ETAB_VILLE                                    NaN
# ETAB_SIRET                                    NaN
# ETAB_GRP                                      NaN
# DT_CREATION                   1970-01-01 00:00:00
# ANNEE CREA                                    NaN
# MOIS CREA                                     NaN
# TRANCHE                                    AUTRES
# DATE_EVT_jour_semaine                       jeudi
# DATE_EVT_jour_semaine_int                       3
# DATE_EVT_jour_mois                              1
# DATE_EVT_mois                             janvier
# DATE_EVT_nth_mois                               1
# DATE_EVT_week                                   1
# DATE_EVT_year                                1970
# DATE_EVT_nth_day                                1
# DT_CREATION_jour_semaine                    jeudi
# DT_CREATION_jour_semaine_int                    3
# DT_CREATION_jour_mois                           1
# DT_CREATION_mois                          janvier
# DT_CREATION_nth_mois                            1
# DT_CREATION_week                                1
# DT_CREATION_year                             1970
# DT_CREATION_nth_day                             1
#
# [38 rows x 49999 columns]
