# %%
import pandas as pd

# %%
path = "https://www.data.gouv.fr/fr/datasets/r/109520e1-47ae-4294-a5b6-6d10c7bae9a6"

# %%
df = pd.read_csv(path, encoding="latin1")

# %%
df
# Out:
#              Num_Acc  senc  catv  occutc   obs  obsm  choc  manv num_veh
# 0       201700000001   0.0     7       0   0.0   2.0   3.0   9.0     B01
# 1       201700000001   0.0    10       0   0.0   2.0   3.0  13.0     A01
# 2       201700000002   0.0     7       0   0.0   0.0   1.0  16.0     A01
# 3       201700000002   0.0     1       0   0.0   0.0   7.0   1.0     B01
# 4       201700000003   0.0    10       0   0.0   2.0   1.0   1.0     C01
# 5       201700000003   0.0     7       0   0.0   2.0   3.0  13.0     A01
# 6       201700000003   0.0     7       0   0.0   2.0   6.0   1.0     B01
# 7       201700000004   0.0     7       0   6.0   0.0   1.0   1.0     A01
# 8       201700000005   0.0    33       0   1.0   2.0   1.0   1.0     B01
# 9       201700000005   0.0     7       0   0.0   2.0   5.0  19.0     A01
# 10      201700000006   0.0    34       0  12.0   0.0   1.0  17.0     A01
# 11      201700000007   0.0     2       0   1.0   0.0   1.0  13.0     A01
# ...

# %%
df.columns
# Out:
# Index(['Num_Acc', 'senc', 'catv', 'occutc', 'obs', 'obsm', 'choc', 'manv',
#        'num_veh'],
#       dtype='object')

# %%
nouvelles_columns = ["Num_Acc", 
                     "sens de circulation", 
                     "catégorie de véhicule", 
                     "Nb d’occupants dans le trans en commun", 
                     "Obstacle fixe heurté", 
                     "Obstacle mobile heurté", 
                     "Point de choc initial", 
                     "Manœuvre principale avant l’accident",
                     "Identifiant du véhicule repris"]

# %%
df.columns
# Out:
# Index(['Num_Acc', 'senc', 'catv', 'occutc', 'obs', 'obsm', 'choc', 'manv',
#        'num_veh'],
#       dtype='object')

# %%
df.columns = nouvelles_columns

# %%
df.head().T
# Out:
#                                                    0             1  \
# Num_Acc                                 201700000001  201700000001
# sens de circulation                                0             0
# catégorie de véhicule                              7            10
# Nb d’occupants dans le trans en commun             0             0
# Obstacle fixe heurté                               0             0
# Obstacle mobile heurté                             2             2
# Point de choc initial                              3             3
# Manœuvre principale avant l’accident               9            13
# Identifiant du véhicule repris                   B01           A01
#
#                                                    2             3  \
# Num_Acc                                 201700000002  201700000002
# sens de circulation                                0             0
# catégorie de véhicule                              7             1
# ...

# %%
git add .
# Out:
#   File "<ipython-input-12-3d6cfb4a5e4d>", line 1
#     git add .
#           ^
# SyntaxError: invalid syntax

# %%
git branch HystenalTeam
# Out:
#   File "<ipython-input-13-da504a9e24ad>", line 1
#     git branch HystenalTeam
#              ^
# SyntaxError: invalid syntax

# %%
# !git branch HystenalTeam

# %%
# !git checkout HystenalTeam
# Out:
# A	.ipynb_checkpoints/00_intro_a_pandas_ibm-checkpoint.ipynb
# A	.ipynb_checkpoints/Untitled1-checkpoint.ipynb
# M	00_intro_a_pandas_ibm.ipynb
# A	Untitled1.ipynb
# M	ib02_battle_vehicules.ipynb
# Switched to branch 'HystenalTeam'

# %%
# !git add .
# Out:
# ...
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory

# %%
# !git commit -m "Rename columns"
# Out:
# [HystenalTeam 291af8a] Rename columns
#  6 files changed, 2172 insertions(+), 57 deletions(-)
#  create mode 100644 .ipynb_checkpoints/00_intro_a_pandas_ibm-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/ib02_battle_vehicules-checkpoint.ipynb
#  create mode 100644 Untitled1.ipynb

# %%
# !git push origin HystenalTeam

# %%
categorie ={
1: "Véhicule en stationnement",
2: "Arbre",
3: "Glissière métallique",
4: "Glissière béton",
5: "Autre glissière",
6: "Bâtiment, mur, pile de pont",
7: "Support de signalisation verticale ou poste d’appel d’urgence",
8: "Poteau",
9: "Mobilier urbain ",
8: "poteau",
10: "Parapet",
11: "Ilot, refuge, borne haute",
12: "Bordure de trottoir",
13: "Fossé, talus, paroi rocheuse",
14: "Autre obstacle fixe sur chaussée",
15: "Autre obstacle fixe sur trottoir ou accotement",
16: "Sortie de chaussée sans obstacle "
    
}

df['obs_enc'] = df.obs.map(categorie)

obs = df.obs_enc.value_counts(dropna=False)
obs.plot.barh(title='Type d\'obstacle fixe')
fig = plt.gcf()
fig.set_size_inches(14, 10)
